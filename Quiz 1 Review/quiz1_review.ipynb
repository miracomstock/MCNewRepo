# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
imdb = Table.read_table('imdb.csv')
imdb.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Votes</th> <th>Rating</th> <th>Title</th> <th>Year</th> <th>Decade</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>88355 </td> <td>8.4   </td> <td>M                  </td> <td>1931</td> <td>1930  </td>
#         </tr>
#         <tr>
#             <td>132823</td> <td>8.3   </td> <td>Singin' in the Rain</td> <td>1952</td> <td>1950  </td>
#         </tr>
#         <tr>
#             <td>74178 </td> <td>8.3   </td> <td>All About Eve      </td> <td>1950</td> <td>1950  </td>
#         </tr>
#         <tr>
#             <td>635139</td> <td>8.6   </td> <td>Léon               </td> <td>1994</td> <td>1990  </td>
#         </tr>
#         <tr>
#             <td>145514</td> <td>8.2   </td> <td>The Elephant Man   </td> <td>1980</td> <td>1980  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (245 rows omitted)</p>

# %%
imdb.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Votes</th> <th>Rating</th> <th>Title</th> <th>Year</th> <th>Decade</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>88355 </td> <td>8.4   </td> <td>M                    </td> <td>1931</td> <td>1930  </td>
#         </tr>
#         <tr>
#             <td>132823</td> <td>8.3   </td> <td>Singin' in the Rain  </td> <td>1952</td> <td>1950  </td>
#         </tr>
#         <tr>
#             <td>74178 </td> <td>8.3   </td> <td>All About Eve        </td> <td>1950</td> <td>1950  </td>
#         </tr>
#         <tr>
#             <td>635139</td> <td>8.6   </td> <td>Léon                 </td> <td>1994</td> <td>1990  </td>
#         </tr>
#         <tr>
#             <td>145514</td> <td>8.2   </td> <td>The Elephant Man     </td> <td>1980</td> <td>1980  </td>
#         </tr>
#         <tr>
#             <td>425461</td> <td>8.3   </td> <td>Full Metal Jacket    </td> <td>1987</td> <td>1980  </td>
#         </tr>
#         <tr>
#             <td>441174</td> <td>8.1   </td> <td>Gone Girl            </td> <td>2014</td> <td>2010  </td>
#         </tr>
#         <tr>
#             <td>850601</td> <td>8.3   </td> <td>Batman Begins        </td> <td>2005</td> <td>2000  </td>
#         </tr>
#         <tr>
#             <td>37664 </td> <td>8.2   </td> <td>Judgment at Nuremberg</td> <td>1961</td> <td>1960  </td>
#         </tr>
#         <tr>
#             <td>46987 </td> <td>8     </td> <td>Relatos salvajes     </td> <td>2014</td> <td>2010  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (240 rows omitted)</p>

# %%
Callie = make_array("Callie", "Oreo")
GoodDog = make_array (10,15)
Table().with_columns("Good Dog", GoodDog, "Name", Callie)
# Out:
# Good Dog | Name
# 10       | Callie
# 15       | Oreo

# %% [markdown]
# # Question 1
# Find the ten movies released in the year 2000 or later with the highest number of votes according to imdb.csv. Format your answer as a table with columns Title and Votes (in that order) of the three requested movies.

# %%
movies2000 = imdb.where("Year", are.above_or_equal_to (2000))
movies2000votes = movies2000.sort("Votes", descending=True)
moviestop10 = movies2000votes.take(np.arange(10))
final_table = moviestop10.select("Title", "Votes")
final_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Title</th> <th>Votes</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>The Dark Knight                                  </td> <td>1473049</td>
#         </tr>
#         <tr>
#             <td>Inception                                        </td> <td>1271949</td>
#         </tr>
#         <tr>
#             <td>The Lord of the Rings: The Fellowship of the Ring</td> <td>1099087</td>
#         </tr>
#         <tr>
#             <td>The Lord of the Rings: The Return of the King    </td> <td>1074146</td>
#         </tr>
#         <tr>
#             <td>The Dark Knight Rises                            </td> <td>997350 </td>
#         </tr>
#         <tr>
#             <td>The Lord of the Rings: The Two Towers            </td> <td>967389 </td>
#         </tr>
#         <tr>
#             <td>Gladiator                                        </td> <td>862216 </td>
#         </tr>
#         <tr>
#             <td>The Avengers                                     </td> <td>862016 </td>
#         </tr>
#         <tr>
#             <td>Batman Begins                                    </td> <td>850601 </td>
#         </tr>
#         <tr>
#             <td>Django Unchained                                 </td> <td>804729 </td>
#         </tr>
#     </tbody>
# </table>

# %%
#movies2000 = imdb.where('Year', are.above_or_equal_to(2000))
#movies2000sorted = movies2000.sort('Votes', descending = True)
movies2000top10 = movies2000sorted.take(np.arange(0,10))
#moviesfinal = movies2000top10.select("Title", "Votes")
#moviesfinal.show()

# %%
movies2000 = imdb.where('Year', are.above_or_equal_to(2000))
movies2000sorted = movies2000.sort('Votes', descending = True)
movies2000top10 = movies2000sorted.take(np.arange(0,10))
movies2000top10
# Out:
# Votes   | Rating | Title                                             | Year | Decade
# 1473049 | 8.9    | The Dark Knight                                   | 2008 | 2000
# 1271949 | 8.7    | Inception                                         | 2010 | 2010
# 1099087 | 8.8    | The Lord of the Rings: The Fellowship of the Ring | 2001 | 2000
# 1074146 | 8.9    | The Lord of the Rings: The Return of the King     | 2003 | 2000
# 997350  | 8.4    | The Dark Knight Rises                             | 2012 | 2010
# 967389  | 8.7    | The Lord of the Rings: The Two Towers             | 2002 | 2000
# 862216  | 8.5    | Gladiator                                         | 2000 | 2000
# 862016  | 8      | The Avengers                                      | 2012 | 2010
# 850601  | 8.3    | Batman Begins                                     | 2005 | 2000
# 804729  | 8.4    | Django Unchained                                  | 2012 | 2010

# %%
item10=movies2000top10.take(9)
item10
# Out:
# Votes  | Rating | Title            | Year | Decade
# 804729 | 8.4    | Django Unchained | 2012 | 2010

# %% [markdown]
# # Question 2
#
# Create a table with columns Title and Votes containing all movies released in 1999.
#
# Next, attach a new column to the table called Percent Votes that contains the percent of votes each movie received when considered among all votes cast for movies released in 1999.
#
# For example, if the total number of votes cast for movies released in 1999 is 200 and "The Matrix" received 30 of them, then the column Percent Votes corresponding to "The Matrix" should 15.

# %%
movies1999 = imdb.where("Year", 1999)
movies1999 = movies1999.select('Title', 'Votes')
votes1999 = movies1999.column("Votes")
sumofvotes = sum(votes1999)
votes = votes1999/sumofvotes *100
new = movies1999.with_column("Percent Votes", votes)
new
# Out:
# Title           | Votes   | Percent Votes
# Fight Club      | 1177098 | 27.4441
# American Beauty | 735056  | 17.1379
# The Sixth Sense | 630994  | 14.7117
# The Matrix      | 1073043 | 25.0181
# The Green Mile  | 672878  | 15.6882

# %%
#movies1999 = imdb.where('Year', 1999)
#movies1999 = movies1999.select('Title', 'Votes')
#votes_column = movies1999.column('Votes')
#total_votes = sum(votes_column)
#percent_column = votes_column / total_votes * 100
#movies1999 = movies1999.with_column('Percent Votes', percent_column)
#movies1999.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Table().with_column("Title")
#
# NameError: name 'Table' is not defined
